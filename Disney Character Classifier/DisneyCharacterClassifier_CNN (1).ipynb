# %% [markdown]
# # **Famous Disney Characters Classifier**
#
# ![download.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **Data Acquisition**

# %%
# !pip install bing-image-downloader

# %%
# !mkdir data

# %%
from bing_image_downloader import downloader

# %%
from IPython.display import IFrame

# %%
IFrame("https://youtube.com/embed/wmiIUN-7qhE", width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="https://youtube.com/embed/wmiIUN-7qhE"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
downloader.download("Woody Of Toy Story", limit = 500, output_dir = "data")
# Out:
# [%] Downloading Images to /content/data/Woody Of Toy Story
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://3.bp.blogspot.com/-GKCOku553Is/U1qkWDtRzUI/AAAAAAABCqg/s4VAMWyHE5c/s1600/woody-toy-story.png
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://diskingdom.com/wp-content/uploads/2015/04/woody8.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i5.walmartimages.com/asr/65439de3-a2ad-4693-a88f-5a2a53b4d3dc_1.dd11d173eea7a05591f14d74594a1b1d.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://4.bp.blogspot.com/-gOhPOo4M9hg/TcGqKJLVWNI/AAAAAAAAAUI/BVdK5lwdXPc/s1600/Woody-Toy-Story-3-640x960.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.rotoscopers.com/wp-content/uploads/2019/10/Toy-Story-4-Woody-.jpg
# [%] File Downloaded !
#
# ...

# %%
downloader.download("Buzz Lightyear Of Toy Story", limit = 500, output_dir = "data")
# Out:
# [%] Downloading Images to /content/data/Buzz Lightyear Of Toy Story
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i5.walmartimages.com/asr/a269c7d7-1c53-4388-976b-93344edf3047_1.86ec9db4a700c1b598b0a4a98fdd5621.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://simplywallpaper.net/pictures/2010/07/16/wp2_buzz_ts3_1600x1200.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i5.walmartimages.com/asr/713bfcb7-9a2f-4c6c-b9bd-caa8112267b3_1.c7017316aefa8f2a7e8ce99eea30c906.jpeg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/originals/80/e1/f6/80e1f6f01659b0f5a9c33d400a46eb1b.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://anewbreedofdragon.com/wp-content/uploads/2015/07/Buzz-Lightyear-Toy-Story.jpg
# [%] File Downloaded !
#
# ...

# %%
IFrame("https://youtube.com/embed/Zi4LMpSDccc", width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="https://youtube.com/embed/Zi4LMpSDccc"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
downloader.download("Elsa Of Frozen", limit = 500, output_dir = "data")
# Out:
# [%] Downloading Images to /content/data/Elsa Of Frozen
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://images.wallpapersden.com/image/download/elsa-frozen_a2xoamyUmZqaraWkpJRoaWZprWplZWU.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://images6.fanpop.com/image/photos/38300000/Frozen-s-Elsa-elsa-queen-frozen-38350823-1024-1024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://images6.fanpop.com/image/photos/35800000/Elsa-frozen-35894856-2448-2448.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://images6.fanpop.com/image/photos/35700000/Elsa-frozen-35781323-500-632.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://images6.fanpop.com/image/photos/37700000/Frozen-Elsa-disney-princess-37732282-1600-900.png
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://images6.fanpop.com/image/photos/35400000/Elsa-disney-frozen-35473514-1024-1023.jpg
# ...

# %%
downloader.download("Olaf Of Frozen", limit = 500, output_dir = "data")
# Out:
# [%] Downloading Images to /content/data/Olaf Of Frozen
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://wdwdailynews.com/wp-content/uploads/2014/12/olaf-frozen-fun-disneyland-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://cdn.collider.com/wp-content/uploads/2017/11/olafs-frozen-adventure-02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/af/2c/03/af2c034f3e2c28bf51bc5d61520fceb2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://1.bp.blogspot.com/--TQRq8GnUBc/XdIox95PPNI/AAAAAAAAhUs/GZMgxrgrc7IN-H2r49HGhCyFQU6yV2wEwCLcBGAsYHQ/s2560/olaf-in-frozen-2-2y-2560x1440.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://images6.fanpop.com/image/photos/38700000/Olaf-frozen-38776093-1024-1024.png
# [%] File Downloaded !
#
# ...

# %%
IFrame("https://youtube.com/embed/_BcYBFC6zfY", width=700, height=350)
# Out:
#         <iframe
#             width="700"
#             height="350"
#             src="https://youtube.com/embed/_BcYBFC6zfY"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
downloader.download("Ralph Of Wreck-It-Ralph", limit = 500, output_dir = "data")
# Out:
# [%] Downloading Images to /content/data/Ralph Of Wreck-It-Ralph
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://static.wikia.nocookie.net/wreckitralph/images/d/dc/Ralph.png/revision/latest?cb=20161113154352
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://sparklyeverafter.com/wp-content/uploads/2012/10/WIR_Ralph_BS_v5.0_Online.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://vignette.wikia.nocookie.net/disney/images/8/89/Wreck_It_Ralph_Poster.jpeg/revision/latest?cb=20181231152041
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http
#
#
# [!!]Indexing page: 1
#
# [%] Indexed 35 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://vignette.wikia.nocookie.net/zootopia-20-by-princebalto/images/a/ac/Nick_handsome_smile.jpg/revision/latest?cb=20160704143935
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://i2.wp.com/bitcast-a-sm.bitgravity.com/slashfilm/wp/wp-content/images/Zootopia-Nick-Wilde.jpg
# [!] Issue getting: http://i2.wp.com/bitcast-a-sm.bitgravity.com/slashfilm/wp/wp-content/images/Zootopia-Nick-Wilde.jpg
# [!] Error:: HTTP Error 400: Bad Request
# [%] Downloading Image #2 from http://images6.fanpop.com/image/photos/39100000/Nick-Wilde-Zootopia-nick-wilde-39132208-999-1451.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/ff/d0/51/ffd0516511037bfc8b57449d62ea2a4f.jpg
# [%] File Downloaded !
#
# ...

# %% [markdown]
# ## **Data Processing**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import DataLoader
from torchvision import models, transforms, datasets

# %%
# %matplotlib inline

# %%
transform = transforms.Compose(
    [
        transforms.Resize((250, 250)),
        transforms.ToTensor(),

        transforms.Normalize(
            mean = [0.485, 0.456, 0.406],
            std = [0.229, 0.224, 0.225]
        )
    ]
)

# %%
data = datasets.ImageFolder(
    "/content/data/",
    transform = transform
)

# %%
data.class_to_idx
# Out:
# {'Buzz Lightyear': 0,
#  'Dory': 1,
#  'Elsa': 2,
#  'Judy Hopps': 3,
#  'Mike Wazowski': 4,
#  'Moana': 5,
#  'Nick Wilde': 6,
#  'Olaf': 7,
#  'Ralph': 8,
#  'Woody': 9}

# %%
from sklearn.model_selection import train_test_split

train_data, test_data = train_test_split(
    data,
    train_size = 0.95,
    random_state = 71
)
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:996: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
print(len(train_data))
print(len(test_data))
# Out:
# 440
# 24

# %%
train_loader = DataLoader(
    train_data,
    batch_size = 10,
    shuffle = True
)

test_loader = DataLoader(
    test_data,
    batch_size = 10,
    shuffle = True
)

# %%
from random import randint

fig = plt.figure(figsize = (15, 15))

for i in range(25):
    fig.add_subplot(5, 5, i + 1)
    random_num = randint(0, 440)

    plt.imshow(
        train_loader.dataset[random_num][0].detach().numpy().transpose((1, 2, 0))
    )

    plt.title(f"Label : {train_loader.dataset[random_num][1]}")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ## **Initialising the Model (ResNet 18)**

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
device
# Out:
# 'cpu'

# %%
Model = models.resnet18(pretrained = True)
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100%|██████████| 44.7M/44.7M [00:00<00:00, 125MB/s]

# %%
Model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %%
for p in Model.parameters():
  p.requires_grad = False

# %%
Model.fc = nn.Linear(512, 10)

# %%
Model.to(device)
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
# ...

# %% [markdown]
# ## **Training the Model**

# %%
criterion = nn.CrossEntropyLoss()# Loss Function
optimizer = torch.optim.Adam(Model.parameters(), lr = 0.001)# Optimizer

# %%
import time

start_time = time.time()

epochs : int = 10
train_losses : int = []
test_losses : int = []
train_correct : int = []
test_correct : int = []

train_corr = 0
test_corr = 0

i : int = 1
while i <= epochs:
  train_corr = 0

  for b, (X_train, y_train) in enumerate(train_loader):
    b += 1

    y_pred = Model(X_train.to(device))
    loss = criterion(y_pred, y_train.to(device))
    predicted = torch.max(y_pred.data, 1)[1]

    batch_corr : int = (predicted == y_train.to(device)).sum()
    train_corr += batch_corr

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    if (b + 1) % 40 == 0:
      print(f"Epoch : {i}, Loss : {loss.item()}, Accuracy : {test_corr / len(test_data)}")

  train_losses.append(loss)
  train_correct.append(train_corr)

  test_corr = 0

  with torch.no_grad():
    for b, (X_test, y_test) in enumerate(test_loader):
      y_val = Model(X_test.to(device))
      predicted = torch.max(y_val.data, 1)[1]
      test_corr += (predicted == y_test.to(device)).sum()

  loss = criterion(y_val, y_test.to(device))
  test_losses.append(loss)
  test_correct.append(test_corr)

  i += 1

current_time = time.time()
print(f"Time taken to train the model : {current_time - start_time} seconds!")
# Out:
# Epoch : 1, Loss : 1.6810795068740845, Accuracy : 0.0
# Epoch : 2, Loss : 0.9578397870063782, Accuracy : 0.5
# Epoch : 3, Loss : 0.6014211177825928, Accuracy : 0.7083333134651184
# Epoch : 4, Loss : 0.9623273015022278, Accuracy : 0.75
# Epoch : 5, Loss : 0.4662867486476898, Accuracy : 0.9166666865348816
# Epoch : 6, Loss : 0.6349722146987915, Accuracy : 0.875
# Epoch : 7, Loss : 0.22159704566001892, Accuracy : 0.9583333134651184
# Epoch : 8, Loss : 0.18850061297416687, Accuracy : 0.875
# Epoch : 9, Loss : 0.24115881323814392, Accuracy : 0.875
# Epoch : 10, Loss : 0.5077828168869019, Accuracy : 0.875
# Time taken to train the model : 587.6729764938354 seconds!

# %% [markdown]
# ## **Analysing the Trained Model**

# %%
# plotting the results

train_losses = [tl.item() for tl in train_losses]
test_losses = [tl.item() for tl in test_losses]

plt.plot(np.array(train_losses), label = "Training loss")
plt.plot(np.array(test_losses), label = "Validation loss")
plt.title("Loss at Epoch")
plt.legend()

# %% [markdown]
# ## **Saving The Model**

# %%
# plotting the results

train_correct = [tl.item() for tl in train_correct]
test_correct = [tl.item() for tl in test_correct]

plt.plot([t / len(train_data) for t in train_correct], label = "Training Accuracy")
plt.plot([t / len(test_data) for t in test_correct], label = "Validation Accuracy")
plt.title("Accuracy at the end of each epoch")
plt.legend()

# %%
with torch.no_grad():
  correct = 0
  for X_test, y_test in test_loader:
    y_pred = Model(X_test.to(device))
    predicted = torch.max(y_pred, 1)[1]
    correct += (predicted == y_test.to(device)).sum()

# %%
# Accuracy
print(f"Length Of Data : {len(test_data)}\nCorrect : {correct.item()}\nAccuracy : {correct.item() / len(test_data) * 100}%")
# Out:
# Length Of Data : 24
# Correct : 22
# Accuracy : 91.66666666666666%

# %%
with torch.no_grad():
  correct = 0
  for X_train, y_train in train_loader:
    y_pred = Model(X_train.to(device))
    predicted = torch.max(y_pred, 1)[1]
    correct += (predicted == y_train.to(device)).sum()

# %%
# Accuracy
print(f"Length Of Data : {len(train_data)}\nCorrect : {correct.item()}\nAccuracy : {correct.item() / len(train_data) * 100}%")
# Out:
# Length Of Data : 440
# Correct : 423
# Accuracy : 96.13636363636363%

# %%
Model.eval()
fig = plt.figure(figsize = (120, 120))

for i in range(10):
    fig.add_subplot(5, 2, i + 1)
    plt.imshow(test_loader.dataset[i][0].detach().numpy().transpose(1, 2, 0))

    with torch.no_grad():
        y_pred = Model(test_loader.dataset[i][0].unsqueeze(0).to(device))
        y_pred_text = "Actual Value : " + [
            j for j in data.class_to_idx if (data.class_to_idx[j]) == (test_loader.dataset[i][1])
        ][0] + "\nPredicted : " + [
            j for j in data.class_to_idx if data.class_to_idx[j] == torch.max(y_pred, 1)[1][0]
        ][0]

    plt.title(y_pred_text, fontdict = {"fontsize" : 100})
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ...

# %% [markdown]
# ## **Saving The Model**

# %%
torch.save(Model.state_dict(), "DisneyCharactersClassifier_CNN_Model.pt")
